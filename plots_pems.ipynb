# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
testdata_716933 = np.array(pd.read_csv('data/pems/pems-d07-9months-2021-station716933-15min.csv')[['Total Flow']][-7863:])
ar_716933 = np.array(pd.read_csv("point_forecasts/ar_pems_716933_test.csv")["0"])
arma_716933 = np.array(pd.read_csv("point_forecasts/arma_pems_716933_test.csv")["0"])
arima_716933 = np.array(pd.read_csv("point_forecasts/arima_pems_716933_test.csv")["0"])
sarima_716933 = np.array(pd.read_csv("point_forecasts/sarima_pems_716933_test.csv")["0"])
slstm_716933 = np.array(pd.read_csv("point_forecasts/slstm_pems_716933_test.csv")["0"])
ssvr_716933 = np.array(pd.read_csv("point_forecasts/ssvr_pems_716933_test.csv")["0"])
sxgboost_716933 = np.array(pd.read_csv("point_forecasts/sxgboost_pems_716933_test.csv")["0"])
slstmarima_716933 = np.array(pd.read_csv("point_forecasts/slstmarima_pems_716933_test.csv")["0"])
ssvrarima_716933 = np.array(pd.read_csv("point_forecasts/ssvrarima_pems_716933_test.csv")["0"])
sxgboostarima_716933 = np.array(pd.read_csv("point_forecasts/sxgboostarima_pems_716933_test.csv")["0"])

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_716933[:100], label='Actual', marker="o")
plt.plot(ar_716933[:100], label='AR', marker="o")
plt.plot(arma_716933[:100], label='ARMA', marker="o")
plt.plot(arima_716933[:100], label='ARIMA', marker="o")
plt.legend(["Actual", "AR", "ARMA", "ARIMA"], loc="upper right")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_716933[:100], label='Actual', marker="o")
plt.plot(sarima_716933[:100], label='SARIMA', marker="o")
plt.plot(slstm_716933[:100], label='SLSTM', marker="o")
plt.plot(ssvr_716933[:100], label='SSVR', marker="o")
plt.plot(sxgboost_716933[:100], label='SXGBoost', marker="o")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_716933[:100], label='Actual', marker="o")
plt.plot(slstmarima_716933[:100], label='SLSTMARIMA', marker="o")
plt.plot(ssvrarima_716933[:100], label='SSVRARIMA', marker="o")
plt.plot(sxgboostarima_716933[:100], label='SXGBoostARIMA', marker="o")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20, loc="upper left")
plt.show()

# %%
testdata_717087 = np.array(pd.read_csv('data/pems/pems-d07-9months-2021-station717087-15min.csv')[['Total Flow']][-7863:])
ar_717087 = np.array(pd.read_csv("point_forecasts/ar_pems_717087_test.csv")["0"])
arma_717087 = np.array(pd.read_csv("point_forecasts/arma_pems_717087_test.csv")["0"])
arima_717087 = np.array(pd.read_csv("point_forecasts/arima_pems_717087_test.csv")["0"])
sarima_717087 = np.array(pd.read_csv("point_forecasts/sarima_pems_717087_test.csv")["0"])
slstm_717087 = np.array(pd.read_csv("point_forecasts/slstm_pems_717087_test.csv")["0"])
ssvr_717087 = np.array(pd.read_csv("point_forecasts/ssvr_pems_717087_test.csv")["0"])
sxgboost_717087 = np.array(pd.read_csv("point_forecasts/sxgboost_pems_717087_test.csv")["0"])
slstmarima_717087 = np.array(pd.read_csv("point_forecasts/slstmarima_pems_717087_test.csv")["0"])
ssvrarima_717087 = np.array(pd.read_csv("point_forecasts/ssvrarima_pems_717087_test.csv")["0"])
sxgboostarima_717087 = np.array(pd.read_csv("point_forecasts/sxgboostarima_pems_717087_test.csv")["0"])

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_717087[:100], label='Actual', marker="o")
plt.plot(ar_717087[:100], label='AR', marker="o")
plt.plot(arma_717087[:100], label='ARMA', marker="o")
plt.plot(arima_717087[:100], label='ARIMA', marker="o")
plt.legend(["Actual", "AR", "ARMA", "ARIMA"], loc="upper right")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_717087[:100], label='Actual', marker="o")
plt.plot(sarima_717087[:100], label='SARIMA', marker="o")
plt.plot(slstm_717087[:100], label='SLSTM', marker="o")
plt.plot(ssvr_717087[:100], label='SSVR', marker="o")
plt.plot(sxgboost_717087[:100], label='SXGBoost', marker="o")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(testdata_717087[:100], label='Actual', marker="o")
plt.plot(slstmarima_717087[:100], label='SLSTMARIMA', marker="o")
plt.plot(ssvrarima_717087[:100], label='SSVRARIMA', marker="o")
plt.plot(sxgboostarima_717087[:100], label='SXGBoostARIMA', marker="o")
plt.ylabel("Traffic Flow",fontsize=20)
plt.legend(fontsize=20)
plt.show()

# %%
loss_lstm = np.array(pd.read_csv("losses/slstm_loss_pems_717087.csv")["0"])

plt.figure(figsize=(20,10))
plt.plot(loss_lstm, color="black")
plt.xlabel("Number of Epoch",fontsize=20)
plt.ylabel("Loss",fontsize=20)
plt.legend(fontsize=20, loc="upper left")
plt.show()
# Out:
# No handles with labels found to put in legend.
