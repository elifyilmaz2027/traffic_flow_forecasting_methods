# %%
from pmdarima.arima import auto_arima
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/istanbul/istanbul_data_del.csv")
data
# Out:
#        Unnamed: 0      _id            DATE_TIME  LONGITUDE   LATITUDE GEOHASH  \
# 0           12913    12914  2020-01-01 00:00:00  29.108276  41.069641  sxk9wk
# 1          621904   621905  2020-01-01 01:00:00  29.108276  41.069641  sxk9wk
# 2          160509   160510  2020-01-01 02:00:00  29.108276  41.069641  sxk9wk
# 3          136167   136168  2020-01-01 03:00:00  29.108276  41.069641  sxk9wk
# 4          684343   684344  2020-01-01 04:00:00  29.108276  41.069641  sxk9wk
# ...           ...      ...                  ...        ...        ...     ...
# 11060     1179972  1179973  2021-04-30 18:00:00  29.108276  41.069641  sxk9wk
# 11061     1197195  1197196  2021-04-30 19:00:00  29.108276  41.069641  sxk9wk
# 11062      551362   551363  2021-04-30 20:00:00  29.108276  41.069641  sxk9wk
# 11063      444616   444617  2021-04-30 21:00:00  29.108276  41.069641  sxk9wk
# 11064      914968   914969  2021-04-30 22:00:00  29.108276  41.069641  sxk9wk
#
# ...

# %%
train_data = data["NUMBER_OF_VEHICLES"].values[:-3500]
test_data = data["NUMBER_OF_VEHICLES"].values[-3500:]

# %%
model = auto_arima(train_data, start_p=1, start_q=0,
                      max_p=5, max_q=0,            
                      d=0,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=84063.193, Time=2.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=103809.100, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=83822.416, Time=0.31 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=83816.720, Time=0.39 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=83812.823, Time=0.47 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=83777.511, Time=0.65 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=83055.995, Time=1.49 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=83059.645, Time=1.22 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 6.632 seconds

# %%
model = auto_arima(train_data, start_p=1, start_q=1,
                      max_p=1, max_q=1,            
                      d=0,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=83816.739, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=103809.100, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=84063.193, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=95706.917, Time=0.68 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=83196.692, Time=2.42 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=87293.626, Time=1.39 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=83609.892, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=93226.640, Time=0.12 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 5.717 seconds

# %%
model = auto_arima(train_data, start_p=1, start_q=1,
                      max_p=5, max_q=5,            
                      d=1,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=83994.220, Time=0.93 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=84192.277, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=84008.590, Time=0.41 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=83993.884, Time=0.71 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=84190.279, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=83993.439, Time=0.72 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=7.01 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=83975.918, Time=1.03 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=17.39 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=12.40 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=10.19 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=83973.919, Time=0.64 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=83991.440, Time=0.46 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=6.96 sec
# ...
